# %%
import numpy as np
import matplotlib as plt
# grafico de linea
# plt.pyplot
plt.pyplot(x, y) # x e y son arrays que contienen los valores para ser representados en la gráfica
plt.xlabel("Titulo eje x") # horizontal
plt.ylabel("Titulo eje y") # vertical
plt.title("Título del gráfico")

#
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       2 import matplotlib as plt
#       3 # grafico de linea
#       4 # plt.pyplot
# ----> 5 plt.pyplot(x, y) # x e y son arrays que contienen los valores para ser representados en la gráfica
#       6 plt.xlabel("Titulo eje x") # horizontal
#       7 plt.ylabel("Titulo eje y") # vertical
#
# NameError: name 'x' is not defined
