# %% [markdown]
# **Vamos a rescatar el ID de Córdoba**

# %%
import pandas as pd
import numpy as np
import matplotlib as mp
import os

path = os.path.join(os.getcwd(),"datos/Datos_meteorológicos_por_hora_por_municipio_España/fronteras_municipios.csv")

s1 = pd.read_csv(path,delimiter=";")
# ID: Official Code Municipality
# Provincia: Official Name Province
# Municipio: Official Name Municipality
# Out:
# Córdoba

# %%
for i in s1:
    print(i)
# Out:
# Geo Point
# Geo Shape
# Year
# Official Code Autonomous Community
# Official Name Autonomous Community
# Official Code Province
# Official Name Province
# Official Code Municipality
# Official Name Municipality
# Iso 3166-3 Area Code
# Type
# Local Name Municipality

# %%
cont = 0
linea = str()

for i in s1["Official Name Municipality"]:
    if i == "Córdoba":
        for l in s1:
            # linea = linea , ", ", s1[l][cont]
            print(s1[l][cont])
            
        break
            
    cont += 1
    
# print(linea)
# Out:
# 37.84929947594361, -4.7017687057332225
# ...

# %%
cont = 0

for i in s1["Official Name Municipality"]:
    if i == "Córdoba":
        print(i," -> L:",cont)
        break
    cont += 1
    
print(s1["Official Code Municipality"][cont])
print(s1["Official Name Province"][cont])
print(s1["Official Name Municipality"][cont])
# Out:
# Córdoba  -> L: 613
# 14021
# Córdoba
# Córdoba
