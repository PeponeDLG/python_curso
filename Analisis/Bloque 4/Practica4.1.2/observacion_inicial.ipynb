# %%
import os
import numpy as np
import matplotlib as mp
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv("./dist_renta_hogares.csv",delimiter=";")

# %%
print(data.Total.count())
puntos = data.Total == "."
vacios = data.Total == pd.NA
print(puntos.sum())
print(data.Total.isnull().sum())
# Out:
# 77274
# 75330
# 1458
