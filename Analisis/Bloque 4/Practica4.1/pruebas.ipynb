# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as mp

data = pd.read_csv("avistamientos_aerostatos.csv")

# %%
display(data.Tecnologia_Detectada.value_counts())
print(data.Tecnologia_Detectada.value_counts().mean())
# Out:
# Tecnologia_Detectada
# Inteligencia de Señales    126
# Vigilancia Radar           119
# Meteorológico              115
# Imagen Óptica              110
# Name: count, dtype: int64
# 117.5
