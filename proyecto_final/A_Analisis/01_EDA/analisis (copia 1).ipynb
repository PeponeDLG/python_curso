# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("station_data//1_enero_junio_2024.csv")
data_aux = pd.read_csv("station_data//2_julio_diciembre_2024.csv")
data = pd.concat([data, data_aux], ignore_index=True)
data_aux = pd.read_csv("station_data//3_enero_junio_2025.csv")
data = pd.concat([data, data_aux], ignore_index=True)
data_aux = pd.read_csv("station_data//4_julio_diciembre_2025.csv")
data = pd.concat([data, data_aux], ignore_index=True)
data_aux = pd.read_csv("station_data//5_enero_abril_2026_.csv")
data = pd.concat([data, data_aux], ignore_index=True)   

data.to_csv("archivo_completo.csv", index=False)

print(data.shape)
# Out:
# (20289, 35)
